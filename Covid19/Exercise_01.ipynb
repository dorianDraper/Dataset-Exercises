# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Read the data from './Covid19/WHO-COVID-19-global-data.csv'
df = pd.read_csv('./WHO-COVID-19-global-data.csv')
df
# Out:
#       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-01-05           AF  Afghanistan       EMRO        NaN
# 1        2020-01-12           AF  Afghanistan       EMRO        NaN
# 2        2020-01-19           AF  Afghanistan       EMRO        NaN
# 3        2020-01-26           AF  Afghanistan       EMRO        NaN
# 4        2020-02-02           AF  Afghanistan       EMRO        NaN
# ...             ...          ...          ...        ...        ...
# 50635    2023-12-17           ZW     Zimbabwe       AFRO       50.0
# 50636    2023-12-24           ZW     Zimbabwe       AFRO       23.0
# 50637    2023-12-31           ZW     Zimbabwe       AFRO     -119.0
# 50638    2024-01-07           ZW     Zimbabwe       AFRO       46.0
# 50639    2024-01-14           ZW     Zimbabwe       AFRO        NaN
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     0         NaN                  0
# ...

# %%
df_index = df.index
df_index
# Out:
# RangeIndex(start=0, stop=50640, step=1)

# %%
df_cols = df.columns
df_cols
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date_reported         object
# Country_code          object
# Country               object
# WHO_region            object
# New_cases            float64
# Cumulative_cases       int64
# New_deaths           float64
# Cumulative_deaths      int64
# dtype: object

# %%
df.shape
# Out:
# (50640, 8)

# %%
df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         NaN                  0

# %%
df.tail()
# Out:
#       Date_reported Country_code   Country WHO_region  New_cases  \
# 50635    2023-12-17           ZW  Zimbabwe       AFRO       50.0
# 50636    2023-12-24           ZW  Zimbabwe       AFRO       23.0
# 50637    2023-12-31           ZW  Zimbabwe       AFRO     -119.0
# 50638    2024-01-07           ZW  Zimbabwe       AFRO       46.0
# 50639    2024-01-14           ZW  Zimbabwe       AFRO        NaN
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 50635            266025         NaN               5730
# 50636            266048         1.0               5731
# 50637            265929        -7.0               5724
# 50638            265975         3.0               5727
# 50639            265975         NaN               5727

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50640 entries, 0 to 50639
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      50640 non-null  object
#  1   Country_code       49163 non-null  object
#  2   Country            49374 non-null  object
#  3   WHO_region         45576 non-null  object
#  4   New_cases          36528 non-null  float64
#  5   Cumulative_cases   50640 non-null  int64
#  6   New_deaths         24161 non-null  float64
#  7   Cumulative_deaths  50640 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#           New_cases  Cumulative_cases    New_deaths  Cumulative_deaths
# count  3.652800e+04      5.064000e+04  24161.000000       5.064000e+04
# mean   2.119320e+04      1.588261e+06    290.267497       1.868103e+04
# std    2.798464e+05      7.146835e+06   1233.708120       7.784856e+04
# min   -6.507900e+04      0.000000e+00  -3432.000000       0.000000e+00
# 25%    5.100000e+01      2.698000e+03      4.000000       2.000000e+01
# 50%    4.680000e+02      3.808400e+04     21.000000       4.100000e+02
# 75%    4.492750e+03      4.622502e+05    110.000000       6.025250e+03
# max    4.047548e+07      1.034368e+08  47687.000000       1.161235e+06

# %%
df['Country'] #with this we see all countries repeated
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 50635       Zimbabwe
# 50636       Zimbabwe
# 50637       Zimbabwe
# 50638       Zimbabwe
# 50639       Zimbabwe
# Name: Country, Length: 50640, dtype: object

# %%
df['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire, Saint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', nan, 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica',
#        "Côte d'Ivoire", 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
df.loc[1:4, 'Country'] #loc is inclusive whilst iloc is not
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[1:8,['Country','New_cases']]
# Out:
#        Country  New_cases
# 1  Afghanistan        NaN
# 2  Afghanistan        NaN
# 3  Afghanistan        NaN
# 4  Afghanistan        NaN
# 5  Afghanistan        NaN
# 6  Afghanistan        NaN
# 7  Afghanistan        NaN
# 8  Afghanistan        1.0

# %%
df.head(6)
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan       EMRO        NaN
# 5    2020-02-09           AF  Afghanistan       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         NaN                  0
# 5                 0         NaN                  0
